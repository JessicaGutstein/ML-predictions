# %%
import numpy as np
import pandas as pd
data = pd.read_csv('Documents/columbia/APAN005/PAC PROJECT/analysis_data.csv')

# %%
data.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'marital_status', 'education_level',
#        'region', 'employment_status', 'owns_home', 'has_auto_loan',
#        'annual_income', 'credit_score', 'credit_limit', 'tenure', 'card_type',
#        'num_transactions', 'avg_transaction_value', 'online_shopping_freq',
#        'reward_points_balance', 'travel_frequency', 'utility_payment_count',
#        'num_children', 'num_credit_cards', 'monthly_spend'],
#       dtype='object')

# %%
data.describe()
# Out:
#         customer_id           age     owns_home  has_auto_loan  annual_income  \
# count  4.000000e+04  40000.000000  40000.000000   40000.000000   40000.000000
# mean   5.516258e+07     49.063900      0.502825       0.502925   62466.009961
# std    2.595662e+07     18.175343      0.499998       0.499998   49656.884438
# min    1.000088e+07     18.000000      0.000000       0.000000    2277.888686
# 25%    3.261957e+07     33.000000      0.000000       0.000000   30478.024000
# 50%    5.541669e+07     49.000000      1.000000       1.000000   48800.257192
# 75%    7.758322e+07     65.000000      1.000000       1.000000   78217.444607
# max    9.999871e+07     80.000000      1.000000       1.000000  720441.690363
#
#        credit_score   credit_limit        tenure  num_transactions  \
# count  40000.000000   40000.000000  40000.000000      40000.000000
# mean     699.878580   14573.193459      9.514575         11.275000
# std       50.247404   11791.285872      5.780889          6.038422
# min      470.895415     461.048761      0.000000          0.000000
# 25%      665.682600    7007.302229      5.000000          7.000000
# 50%      700.208341   11281.194224     10.000000         10.000000
# 75%      733.811768   18282.105567     15.000000         14.000000
# max      850.000000  191517.788605     19.000000         80.000000
#
#        avg_transaction_value  online_shopping_freq  reward_points_balance  \
# count           40000.000000          37992.000000           40000.000000
# mean               37.433152              8.111866            7250.912784
# std                20.037322              3.809252            4975.085861
# min                 4.417843              0.000000             571.531405
# 25%                23.612979              5.000000            4053.616363
# 50%                32.983460              8.000000            5894.362787
# 75%                46.329229             10.000000            8827.159632
# max               240.927091             45.000000           73100.957960
#
#        travel_frequency  utility_payment_count  num_children  \
# count      40000.000000           39202.000000  40000.000000
# mean           2.870675               3.250446      1.109100
# std            2.258988               2.061360      1.152771
# min            0.000000               0.000000      0.000000
# 25%            1.000000               2.000000      0.000000
# 50%            2.000000               3.000000      1.000000
# 75%            4.000000               4.000000      2.000000
# max           29.000000              20.000000      6.000000
#
#        num_credit_cards  monthly_spend
# count       40000.00000   40000.000000
# mean            7.98765    1666.201508
# std             0.19621     537.303898
# min             1.00000      99.080000
# 25%             8.00000    1309.502500
# 50%             8.00000    1609.915000
# 75%             8.00000    1953.395000
# max             8.00000    8924.360000

# %%
#Check for NaNs

# %%
data.isnull().sum()
# Out:
# customer_id                 0
# age                         0
# gender                      0
# marital_status              0
# education_level          1199
# region                      0
# employment_status           0
# owns_home                   0
# has_auto_loan               0
# annual_income               0
# credit_score                0
# credit_limit                0
# tenure                      0
# card_type                   0
# num_transactions            0
# avg_transaction_value       0
# online_shopping_freq     2008
# reward_points_balance       0
# travel_frequency            0
# utility_payment_count     798
# num_children                0
# num_credit_cards            0
# monthly_spend               0
# dtype: int64

# %%
#Remove NaNs with function below

# %%
data = data.fillna(0) # replace NaNs to 0

# %%
#Confirm NaNs were replaced to 0

# %%
data.isnull().sum()
# Out:
# customer_id              0
# age                      0
# gender                   0
# marital_status           0
# education_level          0
# region                   0
# employment_status        0
# owns_home                0
# has_auto_loan            0
# annual_income            0
# credit_score             0
# credit_limit             0
# tenure                   0
# card_type                0
# num_transactions         0
# avg_transaction_value    0
# online_shopping_freq     0
# reward_points_balance    0
# travel_frequency         0
# utility_payment_count    0
# num_children             0
# num_credit_cards         0
# monthly_spend            0
# dtype: int64

# %%
data.dtypes
# Out:
# customer_id                int64
# age                        int64
# gender                    object
# marital_status            object
# education_level           object
# region                    object
# employment_status         object
# owns_home                  int64
# has_auto_loan              int64
# annual_income            float64
# credit_score             float64
# credit_limit             float64
# tenure                     int64
# card_type                 object
# num_transactions           int64
# avg_transaction_value    float64
# online_shopping_freq     float64
# reward_points_balance    float64
# travel_frequency           int64
# utility_payment_count    float64
# num_children               int64
# num_credit_cards           int64
# monthly_spend            float64
# dtype: object

# %%
y = data.monthly_spend
X = data.drop('monthly_spend', axis=1)

# %%
X
# Out:
#        customer_id  age  gender marital_status education_level     region  \
# 0         75570383   77  female        married     high school  northeast
# 1         77915507   52    male        married     high school      south
# 2         31958910   48  female        married       bachelors       west
# 3         76868487   67  female        married     high school  northeast
# 4         69435006   21  female         single       bachelors       west
# ...            ...  ...     ...            ...             ...        ...
# 39995     61684274   76  female        married       bachelors  northeast
# 39996     79543996   35  female         single       bachelors  northeast
# 39997     70938074   70    male        married     high school       west
# 39998     87140605   59  female        married       bachelors       west
# 39999     21453761   55  female        married       bachelors    midwest
#
#       employment_status  owns_home  has_auto_loan  annual_income  ...  tenure  \
# 0            unemployed          1              0   56000.116893  ...       4
# 1            unemployed          1              1   39432.589311  ...      18
# 2            unemployed          1              1   51020.949673  ...      16
# 3            unemployed          1              0   76794.566399  ...       2
# 4         self-employed          1              1   44386.444631  ...       6
# ...                 ...        ...            ...            ...  ...     ...
# 39995        unemployed          1              0   24416.053251  ...       7
# 39996           student          1              0  117569.490084  ...      15
# 39997        unemployed          1              1   54612.784494  ...       6
# 39998        unemployed          1              1   25765.665770  ...      14
# 39999     self-employed          0              1  112745.368483  ...      15
#
#        card_type  num_transactions avg_transaction_value  \
# 0       standard                14             46.144967
# 1           gold                13             88.532219
# 2       standard                 9             78.304445
# 3       standard                10             54.932667
# 4       standard                 8             18.866712
# ...          ...               ...                   ...
# 39995   standard                12             20.020860
# 39996       gold                18             23.743410
# 39997   standard                12             71.729568
# 39998   standard                11             36.541350
# 39999   standard                15             23.729819
#
#        online_shopping_freq  reward_points_balance  travel_frequency  \
# 0                       8.0            6325.578928                 3
# 1                       7.0            5586.814175                 1
# 2                       4.0            6250.225115                 3
# 3                       7.0            8875.409103                 3
# 4                       6.0            5318.021523                 4
# ...                     ...                    ...               ...
# 39995                   6.0            3566.432517                 3
# 39996                   9.0           13504.349780                 2
# 39997                   6.0            6598.036278                 0
# 39998                   4.0            3963.839009                 1
# 39999                  10.0           12715.346145                 4
#
#        utility_payment_count  num_children  num_credit_cards
# 0                        3.0             1                 8
# 1                        1.0             2                 8
# 2                        2.0             0                 8
# 3                        3.0             2                 8
# 4                        3.0             0                 8
# ...                      ...           ...               ...
# 39995                    1.0             2                 8
# 39996                    4.0             0                 8
# 39997                    4.0             1                 8
# 39998                    2.0             1                 8
# 39999                    3.0             1                 8
#
# [40000 rows x 22 columns]

# %%
#Convert Data Types 'Object' to 'Values'

# %%
categorical_features = ['gender','marital_status','education_level','region','employment_status','card_type']

X = pd.get_dummies(X, 
                         prefix_sep = '_', 
                         columns = categorical_features, 
                         drop_first = True)

X.reindex(columns=X.columns, fill_value=0)
X.head()
# Out:
#    customer_id  age  owns_home  has_auto_loan  annual_income  credit_score  \
# 0     75570383   77          1              0   56000.116893    636.767610
# 1     77915507   52          1              1   39432.589311    739.726869
# 2     31958910   48          1              1   51020.949673    650.995903
# 3     76868487   67          1              0   76794.566399    612.779395
# 4     69435006   21          1              1   44386.444631    714.429605
#
#    credit_limit  tenure  num_transactions  avg_transaction_value  ...  \
# 0  10530.389617       4                14              46.144967  ...
# 1   8509.061360      18                13              88.532219  ...
# 2  12462.743330      16                 9              78.304445  ...
# 3  17750.953577       2                10              54.932667  ...
# 4   9861.651561       6                 8              18.866712  ...
#
#    education_level_graduate  education_level_high school  region_northeast  \
# 0                     False                         True              True
# 1                     False                         True             False
# 2                     False                        False             False
# 3                     False                         True              True
# 4                     False                        False             False
#
#    region_south  region_west  employment_status_self-employed  \
# 0         False        False                            False
# 1          True        False                            False
# 2         False         True                            False
# 3         False        False                            False
# 4         False         True                             True
#
#    employment_status_student  employment_status_unemployed  \
# 0                      False                          True
# 1                      False                          True
# 2                      False                          True
# 3                      False                          True
# 4                      False                         False
#
#    card_type_platinum  card_type_standard
# 0               False                True
# 1               False               False
# 2               False                True
# 3               False                True
# 4               False                True
#
# [5 rows x 29 columns]

# %%
len(X.columns)
# Out:
# 29

# %%
X
# Out:
#        customer_id  age  owns_home  has_auto_loan  annual_income  \
# 0         75570383   77          1              0   56000.116893
# 1         77915507   52          1              1   39432.589311
# 2         31958910   48          1              1   51020.949673
# 3         76868487   67          1              0   76794.566399
# 4         69435006   21          1              1   44386.444631
# ...            ...  ...        ...            ...            ...
# 39995     61684274   76          1              0   24416.053251
# 39996     79543996   35          1              0  117569.490084
# 39997     70938074   70          1              1   54612.784494
# 39998     87140605   59          1              1   25765.665770
# 39999     21453761   55          0              1  112745.368483
#
#        credit_score  credit_limit  tenure  num_transactions  \
# 0        636.767610  10530.389617       4                14
# 1        739.726869   8509.061360      18                13
# 2        650.995903  12462.743330      16                 9
# 3        612.779395  17750.953577       2                10
# 4        714.429605   9861.651561       6                 8
# ...             ...           ...     ...               ...
# 39995    686.500318   5355.597132       7                12
# 39996    702.190453  29428.045725      15                18
# 39997    640.175292  13145.734964       6                12
# 39998    704.778891   5561.762833      14                11
# 39999    637.555847  23847.681509      15                15
#
#        avg_transaction_value  ...  education_level_graduate  \
# 0                  46.144967  ...                     False
# 1                  88.532219  ...                     False
# 2                  78.304445  ...                     False
# 3                  54.932667  ...                     False
# 4                  18.866712  ...                     False
# ...                      ...  ...                       ...
# 39995              20.020860  ...                     False
# 39996              23.743410  ...                     False
# 39997              71.729568  ...                     False
# 39998              36.541350  ...                     False
# 39999              23.729819  ...                     False
#
#        education_level_high school  region_northeast  region_south  \
# 0                             True              True         False
# 1                             True             False          True
# 2                            False             False         False
# 3                             True              True         False
# 4                            False             False         False
# ...                            ...               ...           ...
# 39995                        False              True         False
# 39996                        False              True         False
# 39997                         True             False         False
# 39998                        False             False         False
# 39999                        False             False         False
#
#        region_west  employment_status_self-employed  \
# 0            False                            False
# 1            False                            False
# 2             True                            False
# 3            False                            False
# 4             True                             True
# ...            ...                              ...
# 39995        False                            False
# 39996        False                            False
# 39997         True                            False
# 39998         True                            False
# 39999        False                             True
#
#        employment_status_student  employment_status_unemployed  \
# 0                          False                          True
# 1                          False                          True
# 2                          False                          True
# 3                          False                          True
# 4                          False                         False
# ...                          ...                           ...
# 39995                      False                          True
# 39996                       True                         False
# 39997                      False                          True
# 39998                      False                          True
# 39999                      False                         False
#
#        card_type_platinum  card_type_standard
# 0                   False                True
# 1                   False               False
# 2                   False                True
# 3                   False                True
# 4                   False                True
# ...                   ...                 ...
# 39995               False                True
# 39996               False               False
# 39997               False                True
# 39998               False                True
# 39999               False                True
#
# [40000 rows x 29 columns]

# %%
#PCA

# %%
# Scaling
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
scale.fit(X)
X_scaled = scale.transform(X)

# %%
pd.DataFrame(X_scaled)
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.786237  1.537052  0.994366 -1.005867 -0.130213 -1.256020 -0.342868
# 1      0.876586  0.161545  0.994366  0.994167 -0.463857  0.793052 -0.514296
# 2     -0.893951 -0.058536  0.994366  0.994167 -0.230486 -0.972852 -0.178986
# 3      0.836248  0.986849  0.994366 -1.005867  0.288555 -1.733428  0.269504
# 4      0.549864 -1.544084  0.994366  0.994167 -0.364094  0.289591 -0.399583
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995  0.251257  1.482032  0.994366 -1.005867 -0.766267 -0.266251 -0.781739
# 39996  0.939326 -0.773800  0.994366 -1.005867  1.109698  0.046010  1.259832
# 39997  0.607772  1.151910  0.994366  0.994167 -0.158152 -1.188201 -0.121062
# 39998  1.231995  0.546687  0.994366  0.994167 -0.739088  0.097525 -0.764254
# 39999 -1.298676  0.326606 -1.005666  0.994167  1.012548 -1.240333  0.786564
#
#              7         8         9   ...        19        20        21  \
# 0     -0.953944  0.451283  0.434785  ... -0.491038  2.017989  1.729860
# 1      1.467859  0.285674  2.550226  ... -0.491038  2.017989 -0.578082
# 2      1.121887 -0.376759  2.039784  ... -0.491038 -0.495543 -0.578082
# 3     -1.299916 -0.211151  0.873357  ... -0.491038  2.017989  1.729860
# 4     -0.607972 -0.542367 -0.926604  ... -0.491038 -0.495543 -0.578082
# ...         ...       ...       ...  ...       ...       ...       ...
# 39995 -0.434986  0.120066 -0.869004  ... -0.491038 -0.495543  1.729860
# 39996  0.948901  1.113716 -0.683221  ... -0.491038 -0.495543  1.729860
# 39997 -0.607972  0.120066  1.711648  ... -0.491038  2.017989 -0.578082
# 39998  0.775915 -0.045542 -0.044508  ... -0.491038 -0.495543 -0.578082
# 39999  0.948901  0.616891 -0.683899  ... -0.491038 -0.495543 -0.578082
#
#              22        23        24        25        26        27        28
# 0     -0.579236 -0.574540 -0.580853 -0.573386  1.738658 -0.331014  0.818710
# 1      1.726411 -0.574540 -0.580853 -0.573386  1.738658 -0.331014 -1.221434
# 2     -0.579236  1.740521 -0.580853 -0.573386  1.738658 -0.331014  0.818710
# 3     -0.579236 -0.574540 -0.580853 -0.573386  1.738658 -0.331014  0.818710
# 4     -0.579236  1.740521  1.721606 -0.573386 -0.575156 -0.331014  0.818710
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995 -0.579236 -0.574540 -0.580853 -0.573386  1.738658 -0.331014  0.818710
# 39996 -0.579236 -0.574540 -0.580853  1.744027 -0.575156 -0.331014 -1.221434
# 39997 -0.579236  1.740521 -0.580853 -0.573386  1.738658 -0.331014  0.818710
# 39998 -0.579236  1.740521 -0.580853 -0.573386  1.738658 -0.331014  0.818710
# 39999 -0.579236 -0.574540  1.721606 -0.573386 -0.575156 -0.331014  0.818710
#
# [40000 rows x 29 columns]

# %%
# Dimensionality Reduction
from sklearn.decomposition import PCA
pca = PCA(n_components=22)
pca.fit(X_scaled, y)
X_train_pc = pca.transform(X_scaled)
X_train_pc
# Out:
# array([[-0.46603402, -0.22611267, -2.2819093 , ...,  0.07440421,
#         -0.11508748,  0.15005301],
#        [-0.69830765,  0.36736119, -1.65401272, ..., -0.47143891,
#         -0.94926185, -0.37032678],
#        [-1.09246132, -0.8687985 ,  0.72480765, ...,  0.0246184 ,
#         -0.05683767, -0.73424939],
#        ...,
#        [-0.89196097, -0.08727285, -2.03694523, ...,  0.67616281,
#         -1.0130572 , -0.02351387],
#        [-1.81817466, -1.38271738,  0.35230566, ...,  0.38856179,
#         -0.43585525, -0.31654755],
#        [ 1.32653262, -1.29692532,  0.32385979, ..., -0.08825131,
#         -0.26933222, -0.17760493]])

# %%
X_train_pc.shape
# Out:
# (40000, 22)

# %%
import numpy as np
np.sum(pca.explained_variance_ratio_)
# Out:
# np.float64(0.9593043409936572)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train_pc, y)
pred_train = reg.predict(X_train_pc)

# %%
pd.DataFrame(X_train_pc)
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.466034 -0.226113 -2.281909 -1.268615 -0.075451  1.836835  1.774115
# 1     -0.698308  0.367361 -1.654013  1.564008 -0.876886  1.957831 -1.521754
# 2     -1.092461 -0.868799  0.724808 -0.841494 -0.367389  0.300340 -0.265514
# 3     -0.167488 -0.196531 -2.253600 -1.616333 -0.488855  1.835978  1.826577
# 4     -0.934244  1.207687  2.350922 -0.197547 -1.309321 -2.269730  0.040378
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995 -1.550957 -2.021924 -0.254689 -0.189358 -0.366622  1.889496  1.710586
# 39996  2.145692  1.294168  2.345173 -0.115728  1.627617  0.338005  1.583633
# 39997 -0.891961 -0.087273 -2.036945 -0.938364 -0.257994  0.394569 -0.161624
# 39998 -1.818175 -1.382717  0.352306  0.247089 -0.415687  0.401045 -0.239633
# 39999  1.326533 -1.296925  0.323860 -1.935864 -0.847237 -1.355702  0.230312
#
#              7         8         9   ...        12        13        14  \
# 0      0.305882 -1.661004 -1.599954  ... -0.217963  0.629757  0.415158
# 1     -0.190766 -1.872724  2.019307  ...  0.263565  0.650269  2.543429
# 2      2.551255 -0.194462  1.505900  ... -1.521886  1.327109  0.921381
# 3      0.371695 -1.696901 -1.664202  ... -0.216832  0.306140  0.700201
# 4      0.868785 -0.196054 -0.824863  ... -0.240614 -0.044594 -0.375160
# ...         ...       ...       ...  ...       ...       ...       ...
# 39995  0.310962  0.112257 -1.458679  ... -0.358112  0.788536 -0.684179
# 39996 -0.654142  0.171073 -1.045856  ... -0.041388  1.783280  0.048655
# 39997  2.459138 -1.915655  0.885331  ...  0.326914 -0.777899  1.562455
# 39998  2.472291 -0.143437 -0.164895  ... -0.047787  1.116950  0.897183
# 39999 -0.721480  0.014334  0.788768  ... -0.856043  0.510901 -0.989566
#
#              15        16        17        18        19        20        21
# 0     -1.085556 -0.817574 -0.073956 -0.089603  0.074404 -0.115087  0.150053
# 1     -0.827692  0.232131 -0.783231  0.358738 -0.471439 -0.949262 -0.370327
# 2     -0.188618 -0.994242 -0.278015 -0.849984  0.024618 -0.056838 -0.734249
# 3     -1.250134  0.097390 -0.113523 -0.350947  0.072745 -0.224488 -0.003392
# 4      0.688529 -0.646679  0.116881 -0.384632 -0.178117  0.797513 -0.196163
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995 -0.596684 -0.089954 -0.721048 -0.450548  0.013741  0.160111  0.234359
# 39996 -0.285075  0.373182  0.148503  0.265825 -0.610343 -1.583396  0.234023
# 39997 -1.019276 -0.902620  0.635530  0.083138  0.676163 -1.013057 -0.023514
# 39998  0.704998 -0.542254 -0.042231 -0.403039  0.388562 -0.435855 -0.316548
# 39999  1.773772 -0.535281 -0.556948 -0.026592 -0.088251 -0.269332 -0.177605
#
# [40000 rows x 22 columns]

# %%
from sklearn.metrics import root_mean_squared_error
train_pred = reg.predict(X_train_pc)
rmse = root_mean_squared_error(y, train_pred)
rmse
# Out:
# 259.4256880527634

# %%
# Test the model on new unseen data.
scoring_data = pd.read_csv('Documents/columbia/APAN005/PAC PROJECT/scoring_data.csv')
scoring_data_X = scoring_data

# %%
scoring_data.isnull().sum()
# Out:
# customer_id                0
# age                        0
# gender                     0
# marital_status             0
# education_level          301
# region                     0
# employment_status          0
# owns_home                  0
# has_auto_loan              0
# annual_income              0
# credit_score               0
# credit_limit               0
# tenure                     0
# card_type                  0
# num_transactions           0
# avg_transaction_value      0
# online_shopping_freq     492
# reward_points_balance      0
# travel_frequency           0
# utility_payment_count    202
# num_children               0
# num_credit_cards           0
# dtype: int64

# %%
scoring_data = scoring_data.fillna(0)

# %%
scoring_data.isnull().sum()
# Out:
# customer_id              0
# age                      0
# gender                   0
# marital_status           0
# education_level          0
# region                   0
# employment_status        0
# owns_home                0
# has_auto_loan            0
# annual_income            0
# credit_score             0
# credit_limit             0
# tenure                   0
# card_type                0
# num_transactions         0
# avg_transaction_value    0
# online_shopping_freq     0
# reward_points_balance    0
# travel_frequency         0
# utility_payment_count    0
# num_children             0
# num_credit_cards         0
# dtype: int64

# %%
scoring_data.dtypes
# Out:
# customer_id                int64
# age                        int64
# gender                    object
# marital_status            object
# education_level           object
# region                    object
# employment_status         object
# owns_home                  int64
# has_auto_loan              int64
# annual_income            float64
# credit_score             float64
# credit_limit             float64
# tenure                     int64
# card_type                 object
# num_transactions           int64
# avg_transaction_value    float64
# online_shopping_freq     float64
# reward_points_balance    float64
# travel_frequency           int64
# utility_payment_count    float64
# num_children               int64
# num_credit_cards           int64
# dtype: object

# %%
scoring_data_X = scoring_data

# %%
categorical_features = ['gender','marital_status','education_level','region','employment_status','card_type']

scoring_data_X = pd.get_dummies(scoring_data_X, 
                         prefix_sep = '_', 
                         columns = categorical_features, 
                         drop_first = True)

scoring_data_X.reindex(columns=scoring_data_X.columns, fill_value=0)
scoring_data_X.head()
# Out:
#    customer_id  age  owns_home  has_auto_loan  annual_income  credit_score  \
# 0     20451981   68          1              0   28736.958529    644.592407
# 1     23251656   37          0              1  177014.762457    683.032163
# 2     64082260   65          0              0   51625.522861    692.072705
# 3     82505923   33          0              1   62667.564975    735.600403
# 4     89981994   23          1              0   84996.492293    732.301374
#
#    credit_limit  tenure  num_transactions  avg_transaction_value  ...  \
# 0   6295.525826      17                 6              32.444032  ...
# 1  39234.812959      14                17              30.655429  ...
# 2  10842.809736       1                 9              36.063881  ...
# 3  14833.580687       2                12              28.833727  ...
# 4  21540.005940       7                15              12.361809  ...
#
#    education_level_graduate  education_level_high school  region_northeast  \
# 0                     False                        False             False
# 1                     False                         True              True
# 2                     False                        False              True
# 3                     False                        False              True
# 4                     False                        False             False
#
#    region_south  region_west  employment_status_self-employed  \
# 0         False         True                             True
# 1         False        False                            False
# 2         False        False                             True
# 3         False        False                             True
# 4         False        False                             True
#
#    employment_status_student  employment_status_unemployed  \
# 0                      False                         False
# 1                       True                         False
# 2                      False                         False
# 3                      False                         False
# 4                      False                         False
#
#    card_type_platinum  card_type_standard
# 0               False                True
# 1                True               False
# 2               False                True
# 3               False               False
# 4               False               False
#
# [5 rows x 29 columns]

# %%
# Scale test data.
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
scale.fit(scoring_data_X)
scoring_data_X_scaled = scale.transform(scoring_data_X)

# %%
# Test the model on new unseen data.
scoring_data = pd.read_csv('Documents/columbia/APAN005/PAC PROJECT/scoring_data.csv')
from sklearn.decomposition import PCA
pca = PCA(n_components=29)
pca.fit(scoring_data_X_scaled, y)
X_train_pc_2 = pca.transform(scoring_data_X_scaled)
X_train_pc_2
# Out:
# array([[-1.37105823e+00,  8.04506808e-02, -1.70536075e+00, ...,
#          1.32434464e-02,  1.26524375e-02, -6.69114481e-02],
#        [ 5.72333783e+00, -1.40212044e+00,  9.44416727e-01, ...,
#          8.24401440e-02, -1.41781530e-01, -5.25680585e-03],
#        [-9.37133658e-01,  5.76160527e-01, -1.30218775e+00, ...,
#          3.79182881e-02, -3.91587623e-02,  7.64217977e-02],
#        ...,
#        [-1.30202860e+00,  6.48898680e-01, -1.43372207e+00, ...,
#          4.56835166e-02,  1.86724510e-03,  7.64329208e-02],
#        [ 1.26305646e+00, -6.15252137e-03,  2.78477807e+00, ...,
#          4.97768628e-02, -1.59796320e-02,  2.19263393e-05],
#        [-6.43544297e-01,  4.26709150e-01, -1.17684018e+00, ...,
#          1.99398798e-02,  7.76440887e-02,  8.16198713e-02]])

# %%
test_pred = reg.predict(X_train_pc_2)

# %%
submission_file = pd.DataFrame({'customer_id': scoring_data.customer_id, 'monthly_spend': test_pred})
submission_file.to_csv('submission_file_14.csv',index = False)
